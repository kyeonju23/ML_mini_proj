# %% [markdown]
# # Mini Project3
# ### 20181531 김연주

# %%
import numpy as np
import pandas as pd

housing = pd.read_csv("csv/kc_house_data.csv")

housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
housing['date']=  pd.to_datetime(housing['date'])
housing['date'] = housing['date'].apply(lambda x: x.strftime('%Y%m%d'))
housing["date"] = housing["date"].astype('int64')

housing["date"]
# Out:
# 0        20141013
# 1        20141209
# 2        20150225
# 3        20141209
# 4        20150218
#            ...
# 21608    20140521
# 21609    20150223
# 21610    20140623
# 21611    20150116
# 21612    20141015
# Name: date, Length: 21613, dtype: int64

# %%
housing_shuffled=housing.iloc[np.random.permutation(housing.index)].reset_index(drop=True)

# %%
housing.corr()
# Out:
#                      id      date     price  bedrooms  bathrooms  sqft_living  \
# id             1.000000  0.009857 -0.016762  0.001286   0.005160    -0.012258
# date           0.009857  1.000000  0.003033 -0.010493  -0.027523    -0.029791
# price         -0.016762  0.003033  1.000000  0.308350   0.525138     0.702035
# bedrooms       0.001286 -0.010493  0.308350  1.000000   0.515884     0.576671
# bathrooms      0.005160 -0.027523  0.525138  0.515884   1.000000     0.754665
# sqft_living   -0.012258 -0.029791  0.702035  0.576671   0.754665     1.000000
# sqft_lot      -0.132109  0.005599  0.089661  0.031703   0.087740     0.172826
# floors         0.018525 -0.022550  0.256794  0.175429   0.500653     0.353949
# waterfront    -0.002721 -0.003798  0.266369 -0.006582   0.063744     0.103818
# view           0.011592  0.001063  0.397293  0.079532   0.187737     0.284611
# condition     -0.023783 -0.046517  0.036362  0.028472  -0.124982    -0.058753
# ...

# %%
housing = housing.drop(['date'], axis=1)
housing
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608   263000018  360000.0         3       2.50         1530      1131
# 21609  6600060120  400000.0         4       2.50         2310      5813
# 21610  1523300141  402101.0         2       0.75         1020      1350
# 21611   291310100  400000.0         3       2.50         1600      2388
# 21612  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
X = housing.drop(['price'], axis=1) # price 제거 
X
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 2      5631500400         2       1.00          770     10000     1.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530      1131     3.0
# 21609  6600060120         4       2.50         2310      5813     2.0
# 21610  1523300141         2       0.75         1020      1350     2.0
# 21611   291310100         3       2.50         1600      2388     2.0
# 21612  1523300157         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
y = housing['price']
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(random_state=42, n_jobs=-1)

# %%
scores = cross_val_score(model, X, y, 
                         scoring="neg_mean_squared_error", cv=10)
RF_rmse_scores = np.sqrt(-scores)
RF_rmse_scores
# Out:
# array([133000.24414128, 140643.67996108, 118873.99320993, 135658.35602771,
#        112862.61750452, 136672.63503956, 139680.15092406, 119140.51599787,
#        123551.75951474, 131445.31264051])

# %%
RF_rmse_scores.mean()
# Out:
# 129152.92649612627

# %%
from sklearn.ensemble import ExtraTreesRegressor

model = ExtraTreesRegressor(n_estimators=200, random_state=42)

# %%
model.fit(X, y)
# Out:
# ExtraTreesRegressor(n_estimators=200, random_state=42)

# %%
scores = cross_val_score(model, X, y, 
                         scoring="neg_mean_squared_error", cv=10)
Extra_rmse_scores = np.sqrt(-scores)
Extra_rmse_scores
# Out:
# array([128193.30348186, 138339.6832178 , 118742.57775568, 128012.50504831,
#        108351.55393288, 140346.11274826, 131434.54887339, 116874.03946528,
#        121719.87030668, 131130.41870833])

# %%
Extra_rmse_scores.mean()
# Out:
# 126314.4613538461

# %%
y_shuffled=housing_shuffled["price"]
x_shuffled=housing_shuffled.drop(["date","price","id"], axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=50, random_state=42)
forest_reg.fit(x_shuffled, y_shuffled)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=42)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

forest_scores = cross_val_score(forest_reg, x_shuffled, y_shuffled,
                                scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
display_scores(forest_rmse_scores)
# Out:
# Scores: [157872.77282189 126433.8771393  132893.23473275 114644.94277353
#  112446.89949953 131160.78101924 144386.80792145 127943.32696288
#  117212.46846476 115992.19725121]
# Mean: 128098.73085865506
# Standard deviation: 13704.077640342393

# %% [markdown]
# ## 결과: 126533.13478675396

# %%
y_shuffled=housing_shuffled["price"]
x_shuffled=housing_shuffled.drop(["price","id"], axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=50, random_state=42)
forest_reg.fit(x_shuffled, y_shuffled)
# Out:
# RandomForestRegressor(n_estimators=50, random_state=42)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

forest_scores = cross_val_score(forest_reg, x_shuffled, y_shuffled,
                                scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)

# %%
display_scores(forest_rmse_scores)
# Out:
# Scores: [155734.74914413 127839.72024332 134045.87553121 115683.77363866
#  111375.19758786 126461.73820657 145371.37480615 124571.0422808
#  115992.38260341 115626.04796007]
# Mean: 127270.1902002175
# Standard deviation: 13571.028339390325
